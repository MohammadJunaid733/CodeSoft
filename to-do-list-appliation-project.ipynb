# %%
def add_task(todo_list):
    title = input("Enter task title: ")
    description = input("Enter task description: ")
    due_date = input("Enter due date (YYYY-MM-DD): ")
    status = "not completed"  # New tasks are initially set as "not completed"

    task = {
        "title": title,
        "description": description,
        "due_date": due_date,
        "status": status
    }

    todo_list.append(task)
    print("Task added successfully!")

def update_task(todo_list):
    task_index = int(input("Enter the index of the task to update: ")) - 1  # Subtract 1 because the list is 0-indexed

    if task_index >= 0 and task_index < len(todo_list):
        task = todo_list[task_index]

        print("Current task details:")
        view_task_details(task)

        # Ask for updated details
        title = input("Enter updated task title (press Enter to keep current): ").strip() or task["title"]
        description = input("Enter updated task description (press Enter to keep current): ").strip() or task["description"]
        due_date = input("Enter updated due date (YYYY-MM-DD) (press Enter to keep current): ").strip() or task["due_date"]
        status = input("Enter updated status (completed/not completed) (press Enter to keep current): ").strip() or task["status"]

        # Update the task with the new details
        task["title"] = title
        task["description"] = description
        task["due_date"] = due_date
        task["status"] = status

        print("Task updated successfully!")
    else:
        print("Invalid task index. No task updated.")

def view_task_details(task):
    for key, value in task.items():
        print(f"{key}: {value}")

# Sample initial tasks
todo_list = [
    {
        "title": "Task 1",
        "description": "Complete the To-Do List project",
        "due_date": "2023-09-30",
        "status": "not completed"
    },
    {
        "title": "Task 2",
        "description": "Prepare for the internship presentation",
        "due_date": "2023-10-05",
        "status": "not completed"
    },
]

while True:
    print("To-Do List Menu:")
    print("1. Add Task")
    print("2. View Tasks")
    print("3. Update Task")
    print("4. Delete Task")
    print("5. Save to File")
    print("6. Load from File")
    print("7. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        add_task(todo_list)  # Call add_task function
    elif choice == "2":
        for task in todo_list:
            view_task_details(task)
    elif choice == "3":
        update_task(todo_list)  # Call update_task function
    elif choice == "4":
        # Implement the delete_task function here
        pass
    elif choice == "5":
        # Implement the save_to_file function here
        pass
    elif choice == "6":
        # Implement the load_from_file function here
        pass
    elif choice == "7":
        print("Exiting the To-Do List application.")
        break
    else:
        print("Invalid choice. Please try again.")
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[9], line 40
#      37 os.system('Xvfb :1 -screen 0 1024x768x24 &')
#      38 os.environ['DISPLAY'] = ':1'
# ---> 40 root = tk.Tk()
#      41 root.title("To-Do List")
#      43 # Create and place input widgets
#
# File /opt/conda/lib/python3.10/tkinter/__init__.py:2299, in Tk.__init__(self, screenName, baseName, className, useTk, sync, use)
#    2297         baseName = baseName + ext
#    2298 interactive = False
# -> 2299 self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2300 if useTk:
#    2301     self._loadtk()
#
# TclError: couldn't connect to display ":1"
# The XKEYBOARD keymap compiler (xkbcomp) reports:
# > Internal error:   Could not resolve keysym XF86AudioPreset
# > Internal error:   Could not resolve keysym XF86MonBrightnessCycle
# ...
