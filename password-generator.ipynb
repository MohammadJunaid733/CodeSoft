# %%
import random
import string

def generate_password(length, complexity):
    if complexity == "easy":
        characters = string.ascii_letters  # Only letters (upper and lower case)
    elif complexity == "medium":
        characters = string.ascii_letters + string.digits  # Letters and digits
    elif complexity == "strong":
        characters = string.ascii_letters + string.digits + string.punctuation  # Letters, digits, and special characters
    else:
        return "Invalid complexity level"

    password = ''.join(random.choice(characters) for _ in range(length))
    return password

def main():
    print("Password Generator")

    length = int(input("Enter the desired password length: "))
    complexity = input("Enter complexity level (easy, medium, strong): ")

    password = generate_password(length, complexity)

    if password != "Invalid complexity level":
        print(f"Generated Password: {password}")
    else:
        print("Invalid complexity level. Please choose from 'easy', 'medium', or 'strong'.")

if __name__ == "__main__":
    main()
# Out:
# Password Generator
# Enter the desired password length:  10
# Enter complexity level (easy, medium, strong):  strong
# Generated Password: 'sH,;RvK)x
